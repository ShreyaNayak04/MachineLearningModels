# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyaNayak04/MachineLearningModels/blob/main/vehicle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/car data.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
# %matplotlib inline

# %% [markdown]
# **SCATTER PLOT**

# %%
df.plot(kind='scatter',x='Selling_Price',y='Year')
# Out:
# <Axes: xlabel='Selling_Price', ylabel='Year'>

# %% [markdown]
# **HISTOGRAM**

# %%
df['Year'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **BOXPLOT::**

# %%
#first create a pivot table
df.pivot(columns="Fuel_Type",values='Year')
# Out:
# Fuel_Type  CNG  Diesel  Petrol
# 0          NaN     NaN  2014.0
# 1          NaN  2013.0     NaN
# 2          NaN     NaN  2017.0
# 3          NaN     NaN  2011.0
# 4          NaN  2014.0     NaN
# ..         ...     ...     ...
# 296        NaN  2016.0     NaN
# 297        NaN     NaN  2015.0
# 298        NaN     NaN  2009.0
# 299        NaN  2017.0     NaN
# 300        NaN     NaN  2016.0
#
# [301 rows x 3 columns]

# %%
df.pivot(columns="Fuel_Type",values='Year').plot(kind='box',figsize=(10,6))
# Out:
# <Axes: >

# %% [markdown]
# **STAKED BAR CHART**

# %%
df.groupby('Fuel_Type')['Year'].value_counts()
# Out:
# Fuel_Type  Year
# CNG        2011     1
#            2015     1
# Diesel     2015    15
#            2014    14
#            2016     8
#            2012     7
#            2013     5
#            2010     4
#            2017     4
#            2005     1
#            2011     1
#            2018     1
# Petrol     2015    45
#            2016    42
#            2017    31
#            2013    28
#            2014    24
#            2011    17
#            2012    16
#            2010    11
#            2008     7
#            2009     6
#            2006     4
#            2005     3
#            2003     2
#            2007     2
#            2004     1
# Name: Year, dtype: int64

# %%
df.groupby('Fuel_Type')['Year'].value_counts().unstack()
# Out:
# Year       2003  2004  2005  2006  2007  2008  2009  2010  2011  2012  2013  \
# Fuel_Type
# CNG         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   1.0   NaN   NaN
# Diesel      NaN   NaN   1.0   NaN   NaN   NaN   NaN   4.0   1.0   7.0   5.0
# Petrol      2.0   1.0   3.0   4.0   2.0   7.0   6.0  11.0  17.0  16.0  28.0
#
# Year       2014  2015  2016  2017  2018
# Fuel_Type
# CNG         NaN   1.0   NaN   NaN   NaN
# Diesel     14.0  15.0   8.0   4.0   1.0
# Petrol     24.0  45.0  42.0  31.0   NaN

# %%
df.groupby('Fuel_Type')['Year'].value_counts().plot(kind='bar',stacked=True,figsize=(10,6))
# Out:
# <Axes: xlabel='Fuel_Type,Year'>

# %% [markdown]
# **CHECKING FOR A NULL VALUES**

# %%
df['Year'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 296    False
# 297    False
# 298    False
# 299    False
# 300    False
# Name: Year, Length: 301, dtype: bool

# %%
df['Fuel_Type'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 296    False
# 297    False
# 298    False
# 299    False
# 300    False
# Name: Fuel_Type, Length: 301, dtype: bool

# %% [markdown]
# **ANOTHER DATA SET**

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df['year'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4335    False
# 4336    False
# 4337    False
# 4338    False
# 4339    False
# Name: year, Length: 4340, dtype: bool

# %%
df.plot(kind='scatter',x='year',y='selling_price')
# Out:
# <Axes: xlabel='year', ylabel='selling_price'>

# %% [markdown]
# **ANOTHER DATASET**

# %%
import pandas as pd

# %%
df=pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.isnull()
# Out:
#         Time     V1     V2     V3     V4     V5     V6     V7     V8     V9  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 47623  False  False  False  False  False  False  False  False  False  False
# 47624  False  False  False  False  False  False  False  False  False  False
# 47625  False  False  False  False  False  False  False  False  False  False
# 47626  False  False  False  False  False  False  False  False  False  False
# 47627  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
df.dropna()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 47622  43281  1.468348 -1.140941  0.372482 -1.452282 -1.395891 -0.350258
# 47623  43281 -0.696585  1.108944  1.413769 -0.127104  0.018555 -0.455078
# 47624  43282 -0.282262 -1.212401  2.174897 -0.181501 -1.604027 -0.332694
# 47625  43282 -1.513495 -0.206282 -0.702405  1.056423  1.058711 -0.708973
# 47626  43282 -0.659193  1.270953  0.946464 -0.370180  1.619207 -0.288297
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
df.isnull()
# Out:
#         Time     V1     V2     V3     V4     V5     V6     V7     V8     V9  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 47623  False  False  False  False  False  False  False  False  False  False
# 47624  False  False  False  False  False  False  False  False  False  False
# 47625  False  False  False  False  False  False  False  False  False  False
# 47626  False  False  False  False  False  False  False  False  False  False
# 47627  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
df.dropna(axis=1)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 47623  43281 -0.696585  1.108944  1.413769 -0.127104  0.018555 -0.455078
# 47624  43282 -0.282262 -1.212401  2.174897 -0.181501 -1.604027 -0.332694
# 47625  43282 -1.513495 -0.206282 -0.702405  1.056423  1.058711 -0.708973
# 47626  43282 -0.659193  1.270953  0.946464 -0.370180  1.619207 -0.288297
# 47627  43282  1.121749 -0.208202  0.660816  0.857988 -0.823614 -0.422509
#
#              V7        V8        V9       V10       V11       V12       V13  \
# ...

# %%
df.isnull()
# Out:
#         Time     V1     V2     V3     V4     V5     V6     V7     V8     V9  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 47623  False  False  False  False  False  False  False  False  False  False
# 47624  False  False  False  False  False  False  False  False  False  False
# 47625  False  False  False  False  False  False  False  False  False  False
# 47626  False  False  False  False  False  False  False  False  False  False
# 47627  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
df['Amount'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 47623    False
# 47624    False
# 47625    False
# 47626    False
# 47627     True
# Name: Amount, Length: 47628, dtype: bool

# %%
df['Amount'].isnull().value_counts()
# Out:
# False    47627
# True         1
# Name: Amount, dtype: int64

# %%
df.dropna(subset=['Amount','Class'],how='all')
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 47622  43281  1.468348 -1.140941  0.372482 -1.452282 -1.395891 -0.350258
# 47623  43281 -0.696585  1.108944  1.413769 -0.127104  0.018555 -0.455078
# 47624  43282 -0.282262 -1.212401  2.174897 -0.181501 -1.604027 -0.332694
# 47625  43282 -1.513495 -0.206282 -0.702405  1.056423  1.058711 -0.708973
# 47626  43282 -0.659193  1.270953  0.946464 -0.370180  1.619207 -0.288297
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
df['Amount'].isnull().value_counts()
# Out:
# False    47627
# True         1
# Name: Amount, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df2=MinMaxScaler().fit_transform(df[['Amount']])

# %%
df2
# Out:
# array([[1.15886307e-02],
#        [2.08350599e-04],
#        [2.93286386e-02],
#        ...,
#        [6.97006335e-03],
#        [7.66792168e-05],
#        [           nan]])

# %%
import numpy as np

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47628 entries, 0 to 47627
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    47628 non-null  int64
#  1   V1      47628 non-null  float64
#  2   V2      47628 non-null  float64
#  3   V3      47628 non-null  float64
#  4   V4      47628 non-null  float64
#  5   V5      47628 non-null  float64
#  6   V6      47628 non-null  float64
#  7   V7      47628 non-null  float64
#  8   V8      47628 non-null  float64
#  9   V9      47628 non-null  float64
#  10  V10     47628 non-null  float64
#  11  V11     47628 non-null  float64
#  12  V12     47628 non-null  float64
#  13  V13     47628 non-null  float64
#  14  V14     47628 non-null  float64
#  15  V15     47628 non-null  float64
#  16  V16     47628 non-null  float64
#  17  V17     47627 non-null  float64
#  18  V18     47627 non-null  float64
#  19  V19     47627 non-null  float64
# ...

# %%
df2=pd.DataFrame(df2,columns=['Amount'])

# %%
df2.describe()
# Out:
#              Amount
# count  47627.000000
# mean       0.007108
# std        0.019349
# min        0.000000
# 25%        0.000588
# 50%        0.001936
# 75%        0.006437
# max        1.000000

# %%
from sklearn.preprocessing import StandardScaler

# %%
df2=StandardScaler().fit_transform(df[['Class']])

# %%
df2=pd.DataFrame(df2,columns=['Class'])

# %%
df['Amount'].isnull().value_counts()
# Out:
# False    47627
# True         1
# Name: Amount, dtype: int64

# %%
df2.plot(kind='hist',bins=20,figsize=(10,6))
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **SAMPLING THE DATA**

# %%
df
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 47623  43281 -0.696585  1.108944  1.413769 -0.127104  0.018555 -0.455078
# 47624  43282 -0.282262 -1.212401  2.174897 -0.181501 -1.604027 -0.332694
# 47625  43282 -1.513495 -0.206282 -0.702405  1.056423  1.058711 -0.708973
# 47626  43282 -0.659193  1.270953  0.946464 -0.370180  1.619207 -0.288297
# 47627  43282  1.121749 -0.208202  0.660816  0.857988 -0.823614 -0.422509
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...

# %% [markdown]
# **IN ORDER TO GET THOSE COLUMNS THAT WE REQUIRE**

# %%
response='Amount'
y=df['Amount']
y
# Out:
# 0        149.62
# 1          2.69
# 2        378.66
# 3        123.50
# 4         69.99
#           ...
# 47623      5.49
# 47624     10.00
# 47625     89.99
# 47626      0.99
# 47627       NaN
# Name: Amount, Length: 47628, dtype: float64

# %% [markdown]
# **IN ORDER TO GET LIST OF ALL THE COLUMNS IN A DATAFRAME**

# %%
list1=list[df.columns]
list1
# Out:
# list[Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')]

# %% [markdown]
# **CAR DATASET**

# %%
df=pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
response='km_driven'
y=df['km_driven']
y
# Out:
# 0        70000
# 1        50000
# 2       100000
# 3        46000
# 4       141000
#          ...
# 4335     80000
# 4336     80000
# 4337     83000
# 4338     90000
# 4339     40000
# Name: km_driven, Length: 4340, dtype: int64

# %%
list1=list(df.columns)
list1
# Out:
# ['name',
#  'year',
#  'selling_price',
#  'km_driven',
#  'fuel',
#  'seller_type',
#  'transmission',
#  'owner']

# %% [markdown]
# **IN ORDER TO REMOVE THE COLUMN selling_price**

# %%
list1.remove(response)
list1
# Out:
# ['name',
#  'year',
#  'selling_price',
#  'fuel',
#  'seller_type',
#  'transmission',
#  'owner']

# %% [markdown]
# CREATE THE DATAFRAME FOR REMAINING INDEPENDENT VARIABLE'S

# %%
x=df[list1]
x.head()
# Out:
#                        name  year  selling_price    fuel seller_type  \
# 0             Maruti 800 AC  2007          60000  Petrol  Individual
# 1  Maruti Wagon R LXI Minor  2007         135000  Petrol  Individual
# 2      Hyundai Verna 1.6 SX  2012         600000  Diesel  Individual
# 3    Datsun RediGO T Option  2017         250000  Petrol  Individual
# 4     Honda Amaze VX i-DTEC  2014         450000  Diesel  Individual
#
#   transmission         owner
# 0       Manual   First Owner
# 1       Manual   First Owner
# 2       Manual   First Owner
# 3       Manual   First Owner
# 4       Manual  Second Owner

# %% [markdown]
# **SPLIT THE DATA INTO TEST AND TRAIN**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
x_train.shape
# Out:
# (3255, 7)

# %%
y_train.shape
# Out:
# (3255,)

# %%
x_test.shape
# Out:
# (1085, 7)

# %%
y_test.shape
# Out:
# (1085,)

# %% [markdown]
# **BY DEFAULT THE TRAIN_TEST_SPLIT FUNCTION ALLOCATES 25% TO THE TEST DATA**

# %% [markdown]
# **IN ORDER TO SET 40% TO THE TEST DATA**

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y ,test_size=0.4)

# %%
x_test.shape
# Out:
# (1736, 7)

# %% [markdown]
# **STRATIFIED RANDOM SAMPLING**

# %% [markdown]
# **MAIN AIM OF THIS IS TO MAINTAIN EQUAL DISTRIBUTION BETWEEN ORIGINAL TEST AND TRAIN DATA**

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y ,test_size=0.01,random_state=1234)

# %%
x['selling_price'].value_counts(normalize=True)
# Out:
# 300000     0.037327
# 250000     0.028802
# 350000     0.028111
# 550000     0.024654
# 600000     0.023733
#              ...
# 2100000    0.000230
# 828999     0.000230
# 1119000    0.000230
# 746000     0.000230
# 865000     0.000230
# Name: selling_price, Length: 445, dtype: float64

# %%
x_test['selling_price'].value_counts(normalize=True)
# Out:
# 600000     0.045455
# 125000     0.045455
# 1260000    0.022727
# 370000     0.022727
# 240000     0.022727
# 350000     0.022727
# 170000     0.022727
# 1000000    0.022727
# 190000     0.022727
# 1200000    0.022727
# 55000      0.022727
# 285000     0.022727
# 325000     0.022727
# 850000     0.022727
# 225000     0.022727
# 80000      0.022727
# 85000      0.022727
# 500000     0.022727
# 204999     0.022727
# 375000     0.022727
# 115999     0.022727
# 570000     0.022727
# 735000     0.022727
# 750000     0.022727
# 449000     0.022727
# 300000     0.022727
# 1800000    0.022727
# 625000     0.022727
# 700000     0.022727
# 150000     0.022727
# 1100000    0.022727
# 1025000    0.022727
# 530000     0.022727
# 75000      0.022727
# 545000     0.022727
# 120000     0.022727
# 250000     0.022727
# 450000     0.022727
# 426000     0.022727
# 425000     0.022727
# 520000     0.022727
# 2000000    0.022727
# Name: selling_price, dtype: float64
